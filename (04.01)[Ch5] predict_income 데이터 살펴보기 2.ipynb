# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ch5. 소득예측/train_df.csv')

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Education_Status', 'Employment_Status',
#        'Working_Week (Yearly)', 'Industry_Status', 'Occupation_Status', 'Race',
#        'Hispanic_Origin', 'Martial_Status', 'Household_Summary', 'Citizenship',
#        'Birth_Country', 'Tax_Status', 'Gains', 'Losses', 'Dividends',
#        'Income_Status', 'Income'],
#       dtype='object')

# %% [markdown]
# - Gender
# - Education_Status
# - Employment_Status
# - Industry_Status
# - Occupaion_Status
# - Race
# - Birth_Country
# - Tax_Status
# - Income_Status

# %% [markdown]
# ### 범주형 변수

# %%
# 'Gender'
# 남녀간 인당 소득 차이가 있는가?
df.groupby('Gender')[['Income']].agg(['count','sum','mean'])
# Out:
#        Income
#         count      sum        mean
# Gender
# F       10472  5149450  491.735103
# M        9528  5941855  623.620382

# %%
#Educational_Status
# 학력에 따라 소득 차이가 있다.
df.groupby('Education_Status')[['Income']].agg(['count','mean'])
# Out:
#                                Income
#                                 count        mean
# Education_Status
# Associates degree (Academic)      609  782.740558
# Associates degree (Vocational)    741  867.269906
# Bachelors degree                 1956  699.367076
# Children                         2208    0.000000
# College                          3794  651.468108
# Doctorate degree                   87  575.528736
# Elementary (1-4)                  150  343.440000
# Elementary (5-6)                  317  325.116719
# High Freshman                     555  366.794595
# High Junior                       820  483.034146
# High Senior                       242  459.942149
# High Sophomore                    799  408.658323
# High graduate                    6494  664.652140
# Kindergarten                       64  187.640625
# Masters degree                    505  616.102970
# Middle (7-8)                      548  346.883212
# Professional degree               111  547.036036

# %% [markdown]
# - 학력에 따라 재배치
# Children
# Kindergarten (유치원)
# Elementary (1-4) (초등학교 1-4학년)
# Elementary (5-6) (초등학교 5-6학년)
# Middle (7-8) (중학교 7-8학년)
# High Freshman (고등학교 1학년)
# High Sophomore (고등학교 2학년)
# High Junior (고등학교 3학년)
# High Senior (고등학교 4학년)
# High graduate (고등학교 졸업생)
# Associates degree (Vocational) (전문 대학 학사)(2년제)
# Associates degree (Academic) (학사) (2년제)
# College(4년제 대학)(학사학위 취득 이전)
# Bachelors degree (학사)
# Masters degree (석사)
# Doctorate degree (박사)
# Professional degree (전문 학위)

# %%
df['Education_Status'].nunique()
# Out:
# 17

# %%
# 학력에 따른 직업 분포도
con1 = df['Education_Status'] == 'High Junior'

df[con1].groupby(['Industry_Status', 'Occupation_Status'])[['Income']].count()
# Out:
#                                                     Income
# Industry_Status   Occupation_Status
# Agriculture       Admin Support (include Clerical)       1
#                   Farming & Forestry & Fishing          11
#                   Transportation                         1
# Business & Repair Admin Support (include Clerical)       5
#                   Craft & Repair                         7
# ...                                                    ...
# Wholesale         Farming & Forestry & Fishing           1
#                   Handlers/Cleaners                      2
#                   Machine Operators & Inspectors         2
#                   Sales                                  1
#                   Transportation                         3
#
# [113 rows x 1 columns]

# %%
# Employment_Status
df.groupby('Employment_Status')[['Income']].agg(['count','sum','mean'])
# Out:
#                               Income
#                                count      sum        mean
# Employment_Status
# Children or Armed Forces       11142  5439825  488.226979
# Choice Part-Time                 593   470170  792.866779
# Full-Time                       6588  4920762  746.928051
# Not Working                     1221        0    0.000000
# Part-Time (Usually Full-Time)    100    75797  757.970000
# Part-Time (Usually Part-Time)    158   138709  877.905063
# Seeking Full-Time                121    17738  146.595041
# Seeking Part-Time                 77    28304  367.584416

# %%
#
con1 = df['Employment_Status'] == 'Part-Time (Usually Part-Time)'
con2 = df['Employment_Status'] == 'Part-Time (Usually Full-Time)'
con3 = df['Employment_Status'] == 'Children or Armed Forces'

display(df[con1].groupby('Occupation_Status')[['Income']].agg(['count','sum','mean']))
display(df[con2].groupby('Occupation_Status')[['Income']].agg(['count','sum','mean']))
display(df[con3].groupby('Occupation_Status')[['Income']].agg(['count','sum','mean']))
# Out:
#                                  Income
#                                   count    sum         mean
# Occupation_Status
# Admin Support (include Clerical)     20  11875   593.750000
# Craft & Repair                       23  26535  1153.695652
# Farming & Forestry & Fishing          5   2850   570.000000
# Handlers/Cleaners                     5   3767   753.400000
# Machine Operators & Inspectors       24  22142   922.583333
# Management                           13   7414   570.307692
# Professional                         22  18513   841.500000
# Protective Services                   3   4425  1475.000000
# Sales                                 8  10850  1356.250000
# Services                             11   6959   632.636364
# Technicians & Support                 4   3885   971.250000
# Transportation                       20  19494   974.700000
#                                  Income
#                                   count    sum         mean
# Occupation_Status
# ...

# %%
# Industry_Status
df.groupby('Industry_Status')[['Income']].agg(['count','sum','mean'])
# Out:
#                                              Income
#                                               count      sum         mean
# Industry_Status
# Agriculture                                     268   116481   434.630597
# Armed Forces                                      1        0     0.000000
# Business & Repair                               847   547879   646.846517
# Communications                                  195   185803   952.835897
# Construction                                    832   738113   887.155048
# Education                                      1041   641666   616.393852
# Entertainment                                   278   195613   703.643885
# Finance Insurance & Real Estate                 727   454824   625.617607
# Forestry & Fisheries                             26    15393   592.038462
# Hospitals                                       821   853999  1040.193666
# Manufacturing (Durable)                        1575  1429174   907.412063
# ...

# %%
con1 = df['Industry_Status'] == 'Not in universe or children'

print(df[con1].groupby('Employment_Status')['Income'].count())
print('\n')
print(df[con1].groupby('Occupation_Status')['Income'].count())
# 실업자, 구직자 혹은 아이
# Unkown
# Out:
# Employment_Status
# Children or Armed Forces    3489
# Not Working                 1191
# Seeking Full-Time              2
# Seeking Part-Time              6
# Name: Income, dtype: int64
#
#
# Occupation_Status
# Unknown    4688
# Name: Income, dtype: int64

# %%
con1 = df['Occupation_Status'] == 'Sales'
df[con1].groupby(['Industry_Status','Occupation_Status'])[['Income']].agg(['count','sum','mean','std'])
# 같은 직업이여도 산업에 따라 다를까?
# Out:
#                                                                Income          \
#                                                                 count     sum
# Industry_Status                              Occupation_Status
# Business & Repair                            Sales                 52   25063
# Communications                               Sales                 10    3542
# Construction                                 Sales                  6    1400
# Education                                    Sales                  9    4552
# Entertainment                                Sales                 45   22605
# Finance Insurance & Real Estate              Sales                107   34758
# Hospitals                                    Sales                  1       0
# Manufacturing (Durable)                      Sales                 15   10616
# Manufacturing (Non-durable)                  Sales                 39   17112
# ...

# %%
df.groupby('Race')[['Income']].agg(['count','sum','mean','std'])
# 인종,이 소득에 영향을 줄까?
# Out:
#                              Income
#                               count      sum        mean         std
# Race
# Asian/Pacific                   511   268026  524.512720  652.558106
# Black                          2122  1088015  512.730914  650.000693
# Native American/Aleut/Eskimo    226   120476  533.079646  814.033176
# Other                           296   121717  411.206081  798.781921
# White                         16845  9493071  563.554230  705.370880

# %%
df.groupby('Hispanic_Origin')[['Income']].agg(['count','sum','mean','std'])
# Out:
#                           Income
#                            count       sum        mean         std
# Hispanic_Origin
# All other                  17847  10237586  573.630638  703.601923
# Central or South American    326    115729  354.996933  704.794519
# Chicano                       27     17413  644.925926  825.850654
# Cuban                         77     28181  365.987013  536.785572
# Mexican (Mexicano)           625    246896  395.033600  612.260212
# Mexican-American             654    275299  420.946483  638.367939
# Other Spanish                201     76624  381.213930  503.889421
# Puerto Rican                 243     93577  385.090535  893.911846

# %%
df.groupby('Martial_Status')[['Income']].agg(['count','sum','mean','std'])
# Out:
#                              Income
#                               count      sum        mean          std
# Martial_Status
# Divorced                       1633  1130586  692.336803   672.643437
# Married                        9554  6565520  687.201172   757.257352
# Married (Armed Force Spouse)     70    64400  920.000000  1545.847144
# Married (Spouse Absent)         171    90300  528.070175   616.009698
# Separated                       436   275633  632.185780   844.812743
# Single                         7380  2719378  368.479404   555.684854
# Widowed                         756   245488  324.719577   631.973007

# %%
con1 = df['Martial_Status'] == 'Divorced'

df[con1]['Age'].describe()
# Out:
# count    1633.000000
# mean       43.675444
# std        11.606867
# min        15.000000
# 25%        35.000000
# 50%        42.000000
# 75%        51.000000
# max        90.000000
# Name: Age, dtype: float64

# %%
df.groupby('Household_Summary')[['Income']].agg(['count','sum','mean','std'])
# Out:
#                                      Income
#                                       count      sum        mean         std
# Household_Summary
# Child 18 or older                      2192  1136339  518.402828  499.073401
# Child under 18 ever married               4      900  225.000000  262.995564
# Child under 18 never married           2679   172047   64.220605  168.264329
# Group Quarters- Secondary individual     24     9831  409.625000  385.947599
# Householder                            8552  5976260  698.814312  783.043444
# Nonrelative of householder              974   525656  539.687885  525.185704
# Other relative of householder           781   297396  380.788732  682.032974
# Spouse of householder                  4794  2972876  620.124322  718.342633

# %%
df.groupby('Citizenship')[['Income']].agg(['count','sum','mean','std'])
# Native인지 아닌지로 구분하게 되면 출생지를 고려하지 않아도 될 것 같은 생각
# Out:
#                                             Income                       \
#                                              count      sum        mean
# Citizenship
# Foreign-born (Naturalized US Citizen)          588   390801  664.627551
# Foreign-born (Non-US Citizen)                 1258   549075  436.466614
# Native                                       17825  9993598  560.650659
# Native (Born Abroad)                           197   106857  542.421320
# Native (Born in Puerto Rico or US Outlying)    132    50974  386.166667
#
#
#                                                     std
# Citizenship
# Foreign-born (Naturalized US Citizen)        994.966283
# Foreign-born (Non-US Citizen)                595.606167
# Native                                       694.255923
# Native (Born Abroad)                         635.207784
# Native (Born in Puerto Rico or US Outlying)  944.348397

# %%
df.groupby('Birth_Country')[['Income']].agg(['count','sum','mean','std'])
# Out:
#                              Income
#                               count       sum         mean          std
# Birth_Country
# Cambodia                          9      4000   444.444444   434.053888
# Canada                           75     34643   461.906667   687.738994
# China                            34     13357   392.852941   477.443326
# Columbia                         37     11615   313.918919   519.735690
# Cuba                             58     21492   370.551724   562.077387
# Dominican-Republic               49     17629   359.775510   480.575361
# Ecuador                          32     17830   557.187500   552.902805
# El-Salvador                      68     31354   461.088235   513.594379
# England                          50     41486   829.720000  1303.010581
# France                           14      5263   375.928571   406.473098
# Germany                          92     46510   505.543478   641.128288
# ...

# %%
con = df['Birth_Country']=='Peru'

df[con].groupby(['Occupation_Status'])['Income'].agg(['count','sum','mean','std'])
# Out:
#                                   count    sum         mean          std
# Occupation_Status
# Admin Support (include Clerical)      4    500   125.000000   250.000000
# Craft & Repair                        1      0     0.000000          NaN
# Machine Operators & Inspectors        2    900   450.000000   636.396103
# Private Household Services            2      0     0.000000     0.000000
# Professional                          1   1800  1800.000000          NaN
# Protective Services                   2    575   287.500000   406.586399
# Sales                                 3   1700   566.666667   125.830574
# Services                              5  11980  2396.000000  4155.006619
# Transportation                        1      0     0.000000          NaN
# Unknown                               1      0     0.000000          NaN

# %%
df.groupby('Tax_Status')[['Income']].count()
# Out:
#                                                     Income
# Tax_Status
# Head of Household (HOH)                               1217
# Married Filling Jointly both over 65 (MFJ)             469
# Married Filling Jointly both under 65 (MFJ)           8588
# Married Filling Jointly one over 65 & one under...     305
# Nonfiler                                              3874
# Single                                                5547

# %%
df.groupby('Income_Status')[['Income']].count()
# Out:
#                Income
# Income_Status
# Over Median       737
# Under Median    13237
# Unknown          6026
