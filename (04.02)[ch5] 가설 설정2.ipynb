# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ch5. 소득예측/train_df.csv')

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Education_Status', 'Employment_Status',
#        'Working_Week (Yearly)', 'Industry_Status', 'Occupation_Status', 'Race',
#        'Hispanic_Origin', 'Martial_Status', 'Household_Summary', 'Citizenship',
#        'Birth_Country', 'Tax_Status', 'Gains', 'Losses', 'Dividends',
#        'Income_Status', 'Income'],
#       dtype='object')

# %%
def make_hist(df):
    plt.hist(df, bins=10, color='skyblue', edgecolor='black')
    plt.title(f"Histogram of {df.name}")
    plt.xlabel('Value')
    plt.ylabel('Frequency')

# %%
df['Gender'].head(1)
# Out:
# 0    M
# Name: Gender, dtype: object

# %%
# # Gender
# con1 = df['Gender'] == 'M'
# con2 = df['Gender'] == 'F'

# plt.figure(figsize = (10,10))
# plt.subplot(1,2,1)
# make_hist(df[con1]['Occupation_Status'])


# plt.subplot(1,2,2)
# make_hist(df[con2]['Occupation_Status'])

# plt.show()

# %%
con1 = df['Gender'] == 'M'
con2 = df['Gender'] == 'F'
con3 = df['Occupation_Status'] != 'Unknown'
con4 = df['Occupation_Status'] = 'Craft & Repair'

display(df[con1 & con3 & con4].groupby('Occupation_Status')['Income'].agg(['count','mean']).sort_values(by = 'count', ascending = False),
      df[con2 & con3 & con4].groupby('Occupation_Status')['Income'].agg(['count','mean']).sort_values(by = 'count', ascending = False))
# Out:
#                                   count         mean
# Occupation_Status
# Craft & Repair                     1666  1018.744298
# Machine Operators & Inspectors      862   918.068445
# Services                            810   526.223457
# Handlers/Cleaners                   670   676.268657
# Sales                               639   439.591549
# Transportation                      599   870.141903
# Professional                        552   840.231884
# Admin Support (include Clerical)    536   863.977612
# Management                          519   546.231214
# Technicians & Support               243  1111.917695
# Farming & Forestry & Fishing        230   491.682609
# Protective Services                 213   823.281690
# Private Household Services            4   690.250000
#                                   count        mean
# Occupation_Status
# Admin Support (include Clerical)   2173  722.352968
# Services                           1503  504.430472
# ...

# %%
df['Education_Status'].unique()
# Out:
# array(['Middle (7-8)', 'Associates degree (Vocational)', 'High graduate',
#        'Masters degree', 'Bachelors degree', 'High Freshman',
#        'Elementary (1-4)', 'College', 'Children', 'High Sophomore',
#        'Associates degree (Academic)', 'High Junior', 'Elementary (5-6)',
#        'Doctorate degree', 'Professional degree', 'High Senior',
#        'Kindergarten'], dtype=object)

# %%
con4 = df['Education_Status'] == 'Associates degree (Vocational)'
con5 = df['Education_Status'] != 'Children'

print('남성 :', df[con1 & con4 & con5]['Income'].count())
print('여성 :', df[con2 & con4 & con5]['Income'].count())
# Out:
# 남성 : 301
# 여성 : 440

# %%
df[con2 & con4 & con5].groupby('Occupation_Status')[['Income']].count().sort_values(by = 'Income',ascending = False)
# Out:
#                                   Income
# Occupation_Status
# Admin Support (include Clerical)     117
# Professional                          95
# Technicians & Support                 63
# Services                              39
# Unknown                               37
# Management                            29
# Sales                                 29
# Machine Operators & Inspectors        11
# Craft & Repair                         4
# Handlers/Cleaners                      4
# Transportation                         4
# Farming & Forestry & Fishing           3
# Private Household Services             3
# Protective Services                    2

# %%
con = df['Industry_Status'] == 'Entertainment'

df[con].groupby('Occupation_Status')['Income'].count()
# Out:
# Occupation_Status
# Admin Support (include Clerical)    33
# Craft & Repair                      14
# Farming & Forestry & Fishing        10
# Handlers/Cleaners                    1
# Machine Operators & Inspectors       2
# Management                          16
# Professional                        47
# Protective Services                 13
# Sales                               45
# Services                            93
# Technicians & Support                2
# Transportation                       2
# Name: Income, dtype: int64

# %%
df[con2 & con4 & con5].groupby('Industry_Status')[['Income']].count().sort_values(by = 'Income',ascending = False)
# Out:
#                                               Income
# Industry_Status
# Hospitals                                         98
# Medical (except Hospitals)                        78
# Retail                                            49
# Not in universe or children                       37
# Education                                         24
# Finance Insurance & Real Estate                   21
# Manufacturing (Non-durable)                       17
# Public Administration                             17
# Other professional services                       15
# Manufacturing (Durable)                           15
# Wholesale                                         12
# Business & Repair                                 10
# Personal Services (except Private Household)       9
# Social Services                                    9
# Construction                                       5
# Transportation                                     5
# ...

# %%
df[con1 & con4 & con5].groupby('Occupation_Status')[['Income']].count().sort_values(by = 'Income',ascending = False)
# Out:
#                                   Income
# Occupation_Status
# Craft & Repair                       100
# Machine Operators & Inspectors        31
# Technicians & Support                 26
# Management                            19
# Services                              19
# Professional                          18
# Unknown                               18
# Admin Support (include Clerical)      16
# Sales                                 15
# Transportation                        15
# Protective Services                   11
# Handlers/Cleaners                      7
# Farming & Forestry & Fishing           6

# %%
df[con1 & con4 & con5].groupby('Industry_Status')[['Income']].count().sort_values(by = 'Income',ascending = False)
# Out:
#                                               Income
# Industry_Status
# Manufacturing (Durable)                           45
# Retail                                            36
# Construction                                      31
# Business & Repair                                 28
# Manufacturing (Non-durable)                       23
# Transportation                                    20
# Not in universe or children                       18
# Public Administration                             14
# Hospitals                                         13
# Utilities & Sanitary                              12
# Wholesale                                         10
# Education                                          9
# Communications                                     8
# Other professional services                        8
# Finance Insurance & Real Estate                    6
# Agriculture                                        5
# ...

# %%
con6 = df['Industry_Status'] == 'Business & Repair'

df[con6].groupby('Occupation_Status')['Income'].count()
# Out:
# Occupation_Status
# Admin Support (include Clerical)    184
# Craft & Repair                      150
# Farming & Forestry & Fishing          1
# Handlers/Cleaners                    70
# Machine Operators & Inspectors       63
# Management                           62
# Professional                         34
# Protective Services                  71
# Sales                                52
# Services                            106
# Technicians & Support                29
# Transportation                       25
# Name: Income, dtype: int64

# %%
# 산업별 직업 간 평균 Income 차이 보기

# %%
df['Employment_Status'].unique()
# Out:
# array(['Full-Time', 'Children or Armed Forces', 'Not Working',
#        'Seeking Full-Time', 'Choice Part-Time',
#        'Part-Time (Usually Part-Time)', 'Part-Time (Usually Full-Time)',
#        'Seeking Part-Time'], dtype=object)

# %%
df.groupby('Employment_Status')['Income'].agg(['count','mean']).sort_values(by = 'mean', ascending = False)
# Out:
#                                count        mean
# Employment_Status
# Part-Time (Usually Part-Time)    158  877.905063
# Choice Part-Time                 593  792.866779
# Part-Time (Usually Full-Time)    100  757.970000
# Full-Time                       6588  746.928051
# Children or Armed Forces       11142  488.226979
# Seeking Part-Time                 77  367.584416
# Seeking Full-Time                121  146.595041
# Not Working                     1221    0.000000

# %%
# Part-Time의 소득이 가장 높던데, 기술직이 많을 것 같다.

# %%
con1 = df['Employment_Status'] == 'Part-Time (Usually Part-Time)'
con2 = df['Employment_Status'] == 'Choice Part-Time'
con3 = df['Employment_Status'] == 'Part-Time (Usually Full-Time)'

display(df[con1].groupby('Occupation_Status')[['Income']].count().sort_values(by = 'Income', ascending = False))
display(df[con2].groupby('Occupation_Status')[['Income']].count().sort_values(by = 'Income', ascending = False))
display(df[con3].groupby('Occupation_Status')[['Income']].count().sort_values(by = 'Income', ascending = False))
# Out:
#                                   Income
# Occupation_Status
# Machine Operators & Inspectors        24
# Craft & Repair                        23
# Professional                          22
# Admin Support (include Clerical)      20
# Transportation                        20
# Management                            13
# Services                              11
# Sales                                  8
# Farming & Forestry & Fishing           5
# Handlers/Cleaners                      5
# Technicians & Support                  4
# Protective Services                    3
#                                   Income
# Occupation_Status
# Admin Support (include Clerical)     113
# Services                              83
# Professional                          71
# Craft & Repair                        60
# Sales                                 56
# Machine Operators & Inspectors        54
# Management                            52
# Handlers/Cleaners                     33
# ...

# %%
# Hispanic_Origin과 Birth_Country / Citizenship

# %%
# Household가 Non-relative인 경우, 살펴보기

# %%
# 결혼상태 & Household_Summary

# %%
# Profit 칼럼 생성

# %%
# Profit과 Income 관계

# %%
# Martial_Status와 Income_status
